# %%
import pandas as pd

# %%
#wikipedia 일인당 명목 국내 총생산순 나라 목록
dfs = pd.read_html('https://ko.wikipedia.org/wiki/%EC%9D%BC%EC%9D%B8%EB%8B%B9_%EB%AA%85%EB%AA%A9_%EA%B5%AD%EB%82%B4_%EC%B4%9D%EC%83%9D%EC%82%B0%EC%88%9C_%EB%82%98%EB%9D%BC_%EB%AA%A9%EB%A1%9D')

# %%
dfs
# Out:
# [                                                   0  \
#  0  >$60,000 $50,000 - $60,000 $40,000 - $50,000 $...
#
#                                                     1  \
#  0  $20,000 - $30,000 $10,000 - $20,000 $5,000 - $...
#
#                                               2
#  0  $1,000 - $2,500 $500 - $1,000 <$500 No data  ,
#        순위         국가/령 일인당 GDP[2]
#        전체   국가    국가/령 일인당 GDP[2]
#  0      1    1     모나코     234317
#  1      2    2  리히텐슈타인     169260
#  2      3    3   룩셈부르크     133745
#  3      4    -  버뮤다[3]     112653
#  4      5    4    아일랜드     101109
#  ..   ...  ...     ...        ...
#  208  209  191     남수단        400
#  209  210  192  아프가니스탄        373
#  210  211  193     부룬디        311
#  211  212  194      예멘        302
#  212   세계   세계      세계      12229
#
#  [213 rows x 4 columns],
#               국가    대륙  국제 통화 기금              세계은행
#               국가    대륙       US$      연도       US$      연도
# ...

# %%
df = dfs[3]
df.iloc[0]
# Out:
# 0    국제 통화 기금 (2021)[13]
# 1        세계은행 (2018)[14]
# 2      유엔 통계국 (2017)[15]
# Name: 0, dtype: object

# %%
#국제 통화 기금 (2021) 1인당 GDP
dfs[4]
# Out:
#       순위  국가/영토       미화$
# 0      1  룩셈부르크  131300.0
# 1      2   아일랜드  102390.0
# 2      3    스위스   93515.0
# 3      4   노르웨이   82244.0
# 4      5     미국   69375.0
# ..   ...    ...       ...
# 186  184    니제르     405.0
# 187  185    말라위     371.0
# 188  186  에리트레아     343.0
# 189  187    부룬디     310.0
# 190  188    남수단     275.0
#
# [191 rows x 3 columns]

# %%
#세계은행 (2018) 1인당 GDP
dfs[5]
# Out:
#       순위          국가/영토     미화$
# 0      —     모나코 (2017)  166726
# 1      —  리히텐슈타인 (2016)  165028
# 2      1          룩셈부르크  114340
# 3      —            마카오   86355
# 4      —     버뮤다 (2013)   85748
# ..   ...            ...     ...
# 222  178         마다가스카르     460
# 223  179            니제르     411
# 224  180            말라위     389
# 225    —     남수단 (2016)     283
# 226  181            부룬디     275
#
# [227 rows x 3 columns]

# %%
#유엔 통계국 (2017) 1인당 GDP
dfs[6]
# Out:
#       순위   국가/영토     미화$
# 0      1  리히텐슈타인  166022
# 1      2     모나코  165421
# 2      3   룩셈부르크  106806
# 3      —     버뮤다  102192
# 4      —     마카오   80893
# ..   ...     ...     ...
# 217  190    모잠비크     426
# 218  191     니제르     378
# 219  192     말라위     340
# 220  193     부룬디     290
# 221  194    소말리아     104
#
# [222 rows x 3 columns]
